# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time 
import pandas as pd
from selenium.webdriver.support.ui import Select 
from selenium.webdriver import ActionChains

# %% [markdown]
# # Prob 5 Scrape the details of trending repositories on Github.com.

# %% [raw]
# Url = https://github.com/
# You have to find the following details:
# A) Repository title
# B) Repository description
# C) Contributors count
# D) Language used
# Note: - From the home page you have to click on the trending option from Explore menu through code.

# %%
driver= webdriver.Chrome(r"C:\Users\arkay\Downloads\chromedriver_win32 (1)\chromedriver.exe")
url='https://github.com/'
driver.get(url)
time.sleep(5)

# %%
r_title=[]
r_desc=[]
c_count=[]
l_used=[]

# %%
r_tags=driver.find_elements_by_xpath("/html/body/div[4]/main/div[3]/div/div[2]/article/h1/a/span")
for i in r_tags:
    dataset=i.text
    r_title.append(dataset)
rd_tags=driver.find_elements_by_xpath("/html/body/div[4]/main/div[3]/div/div[2]/article/p")
for i in rd_tags:
    dataset=i.text
    r_desc.append(dataset)
            
c_tags=driver.find_elements_by_xpath("/html/body/div[4]/main/div[3]/div/div[2]/article/div[2]/a[2]")
for i in c_tags:
    dataset=i.text
    c_count.append(dataset)
l_tags=driver.find_elements_by_xpath("/html/body/div[4]/main/div[3]/div/div[2]/article/div[2]/span[1]/span[2]")
for i in l_tags:
    dataset=i.text
    l_used.append(dataset)

GH=pd.DataFrame({})
GH['Repository_Name']=r_title
GH['Contributors_count']=c_count
GH['Language_Used']=l_used
GH
# Out:
#        Repository_Name Contributors_count     Language_Used
# 0            owncast /                 85                Go
# 1            utkusen /                 66            Python
# 2        DevUtilsApp /                 69       Objective-C
# 3         GitSquared /              1,407        JavaScript
# 4         FlaxEngine /                 49               C++
# ..                 ...                ...               ...
# 95          trekhleb /              2,960  Jupyter Notebook
# 96             ly525 /                707        JavaScript
# 97       storybookjs /              5,666        TypeScript
# 98  FirebaseExtended /              1,656              Dart
# 99           FreeCAD /              2,091               C++
#
# [100 rows x 3 columns]

# %% [markdown]
# # Prob -7 Scrape the details of Data science recruiters from naukri.com.

# %% [raw]
# Url = https://www.naukri.com/
# You have to find the following details:
# A) Name
# B) Designation
# C) Company
# D) Skills they hire for
# E) Location
# Note: - From naukri.com homepage click on the recruiters option and the on the search pane type Data science and
# click on search. All this should be done through code

# %%
driver= webdriver.Chrome(r"C:\Users\arkay\Downloads\chromedriver_win32 (1)\chromedriver.exe")
url='https://www.naukri.com/data-science-recruiters'
driver.get(url)
time.sleep(5)
driver.maximize_window()

# %%
driver.find_element_by_xpath("/html/body/div[1]/div/div/ul[1]/li[2]/a").click()
time.sleep(5)

# %%
name=[]
des=[]
com=[]
skil=[]
loc=[]

# %%
n_tags=driver.find_elements_by_xpath("//*[@id='tabP-1']/div/div/div[1]/div[1]/p/a[1]/span")
for i in n_tags:
    dataset=i.text
    name.append(dataset)
d_tags=driver.find_elements_by_xpath("//*[@id='tabP-1']/div/div/div[1]/div[1]/p/span[1]")
for i in d_tags:
    dataset=i.text
    des.append(dataset)
c_tags=driver.find_elements_by_xpath("//*[@id='tabP-1']/div/div/div[1]/div[1]/p/a[2]")
for i in c_tags:
    dataset=i.text
    com.append(dataset)
s_tags=driver.find_elements_by_xpath("//*[@id='tabP-1']/div/div/div[1]/div[2]")
for i in s_tags:
    dataset=i.text
    skil.append(dataset)
l_tags=driver.find_elements_by_xpath("//*[@id='tabP-1']/div/div/div[1]/div[1]/p/span[2]/small")
for i in l_tags:
    dataset=i.text
    loc.append(dataset)

# %%
N=pd.DataFrame({})
N['Name']=name
N['Designation']=des
N['Company']=com
N['Skills_they_hire_for']=skil
N
# Out:
#                                              Name  \
# 0                                    Aakash Harit
# 1                            shravan Kumar Gaddam
# 2                    Talent Acquisition Executive
# 3                                    Anik Agrawal
# 4                        MARSIAN Technologies LLP
# 5                                    subhas patel
# 6                                  Jitendra Singh
# 7    Abhishek - Only Analytics Hiring - India and
# 8   Institute for Financial Management and Resear
# 9                                     Balu Ramesh
# 10                                  Asif Lucknowi
# 11                                InstaFinancials
# 12                                Kalpana Dumpala
# 13                                        Mubarak
# 14                                 Kushal Rastogi
# 15                                  Manisha Yadav
# 16                                   Kapil Devang
# 17                                          Rakhi
# ...

# %% [markdown]
# # Prob 2 -Scrape the details team India’s international fixtures from bcci.tv.

# %% [raw]
# Url = https://www.bcci.tv/.
# You need to find following details:
# A) Match title (I.e. 1
# st ODI)
# B) Series
# C) Place
# D) Date
# E) Time
# Note: - From bcci.tv home page you have reach to the international fixture page through code

# %%
driver= webdriver.Chrome(r"C:\Users\arkay\Downloads\chromedriver_win32 (1)\chromedriver.exe")
url='https://www.bcci.tv/international/fixtures'
driver.get(url)
time.sleep(5)
driver.maximize_window()

# %%
m=[]
s=[]
p=[]
d=[]
t=[]

# %%
m_tags=driver.find_elements_by_xpath("/html/body/div[4]/div/div/div[2]/section/div/div/a/div[2]/div[2]/p/strong")
for i in m_tags:
    dataset=i.text
    m.append(dataset)
s_tags=driver.find_elements_by_xpath("/html/body/div[4]/div/div/div[2]/section/div/div/a/div[2]/div[1]/span[2]")
for i in s_tags:
    dataset=i.text
    s.append(dataset)
p_tags=driver.find_elements_by_xpath("/html/body/div[4]/div/div/div[2]/section/div/div/a/div[2]/div[2]/p/span")
for i in p_tags:
    dataset=i.text
    p.append(dataset)
d_tags=driver.find_elements_by_xpath("/html/body/div[4]/div/div/div[2]/section/div/div/a/div[2]/div[2]/span/strong")
#d_tags=driver.find_elements_class_name("fixture__datetime tablet-only")
for i in d_tags:
    dataset=i.text
    d.append(dataset)
# /html/body/div[4]/div/div/div[2]/section/div/div/a[2]/div[2]/div[2]/span/strong
t_tags=driver.find_elements_by_class_name("fixture__local-time")
for i in t_tags:
    dataset=i.text
    t.append(dataset)

# %%
BCCI=pd.DataFrame({})
BCCI['Event']=m
BCCI['Series']=s
BCCI['Place']=p
BCCI['Date']=d
BCCI
# Out:
#        Event                     Series  \
# 0   2nd Test  AUSTRALIA V INDIA 2020/21
# 1   3rd Test  AUSTRALIA V INDIA 2020/21
# 2   4th Test  AUSTRALIA V INDIA 2020/21
# 3   1st Test       INDIA V ENGLAND 2021
# 4   2nd Test       INDIA V ENGLAND 2021
# 5   3rd Test       INDIA V ENGLAND 2021
# 6   4th Test       INDIA V ENGLAND 2021
# 7   1st T20I       INDIA V ENGLAND 2021
# 8   2nd T20I       INDIA V ENGLAND 2021
# 9   3rd T20I       INDIA V ENGLAND 2021
# 10  4th T20I       INDIA V ENGLAND 2021
# 11  5th T20I       INDIA V ENGLAND 2021
# 12   1st ODI       INDIA V ENGLAND 2021
# 13   2nd ODI       INDIA V ENGLAND 2021
# 14   3rd ODI       INDIA V ENGLAND 2021
# 15  1st Test       ENGLAND V INDIA 2021
# 16  2nd Test       ENGLAND V INDIA 2021
# 17  3rd Test       ENGLAND V INDIA 2021
# 18  4th Test       ENGLAND V INDIA 2021
# 19  5th Test       ENGLAND V INDIA 2021
#
#                                             Place Date
# 0             Melbourne Cricket Ground, Melbourne
# ...
